# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin

# Base URL for LSE website
base_url = "https://www.lse.ac.uk"

# URL for the course list page
url = "https://www.lse.ac.uk/resources/calendar2016-2017/programmeRegulations/undergraduate/2016_outsideOptions.htm"

# Send a GET request to the URL
page = requests.get(url)
soup = BeautifulSoup(page.content, "lxml")

# Initialize a list to store course data
course_data = []

# Loop through all anchor tags with href attributes
for a in soup.find_all("a", href=True):
    link = a["href"]
    
    # Skip empty or malformed links
    if not link or link.startswith("#"):
        continue
    
    # Handle relative links using urljoin
    full_url = urljoin(base_url, link)
    
    # Look for course codes (the course code pattern is letters followed by numbers)
    name = a.get_text(strip=True)
    if len(name) >= 5 and name[:2].isalpha() and name[2:].isdigit():
        # Add course code and URL to the data list
        course_data.append({'Course Code': name, 'URL': full_url})

# Create a DataFrame from the course data
df_courses = pd.DataFrame(course_data)

# Remove duplicates, in case any course code is listed more than once
df_courses = df_courses.drop_duplicates(subset='Course Code')

# Set 'Course Code' as the index column
df_courses.set_index('Course Code', inplace=True)

# Display the DataFrame with course codes and URLs
print("Course DataFrame:")
print(df_courses)

# Function to extract prerequisites from a course page
def get_prerequisites(course_url):
    try:
        # Send a GET request to the course page
        page = requests.get(course_url)
        
        # If the URL returns a 404, return 0 as there are no prerequisites
        if page.status_code == 404:
            print(f"Page not found: {course_url}")
            return [0]
        
        soup = BeautifulSoup(page.content, "lxml")

        # Look for a possible prerequisite heading (commonly 'Prerequisite')
        prereq_section = soup.find(string=lambda text: 'prerequisite' in text.lower())
        
        if prereq_section:
            # Find the parent tag of the prereq section and try to extract course codes
            prereqs = []
            for link in prereq_section.find_parent().find_all('a', href=True):
                course_code = link.get_text(strip=True)
                # Check if the text is a valid course code (starts with letters and followed by numbers)
                if len(course_code) >= 5 and course_code[:2].isalpha() and course_code[2:].isdigit():
                    prereqs.append(course_code)
            
            # Return prerequisites if found, otherwise return [0]
            return prereqs if prereqs else [0]
        return [0]  # No prerequisites found
        
    except Exception as e:
        # Handle errors gracefully and return 0 in case of failure
        print(f"Error fetching prerequisites for {course_url}: {e}")
        return [0]


# Now, let's extract the prerequisites for each course from the dataframe
course_data_with_prereqs = []

# Loop through each course in the DataFrame
for index, row in df_courses.iterrows():
    course_code = index
    course_url = row['URL']
    
    # Get prerequisites for the course
    prerequisites = get_prerequisites(course_url)
    
    # Append the course data with prerequisites to the list
    for prereq in prerequisites:
        course_data_with_prereqs.append({'Course Code': course_code, 'Prerequisites': prereq})

# Create a new DataFrame with the course codes and their prerequisites
df_prereqs = pd.DataFrame(course_data_with_prereqs)

# Set 'Course Code' as the index column
df_prereqs.set_index('Course Code', inplace=True)

# Display the DataFrame with prerequisites
print("Course Prerequisites DataFrame:")
print(df_prereqs)
# Out:
# Course DataFrame:
#                                                            URL
# Course Code
# AC100        https://www.lse.ac.uk/courseGuides/AC/2016_AC1...
# AN100        https://www.lse.ac.uk/courseGuides/AN/2016_AN1...
# AN101        https://www.lse.ac.uk/courseGuides/AN/2016_AN1...
# AN102        https://www.lse.ac.uk/courseGuides/AN/2016_AN1...
# EC100        https://www.lse.ac.uk/courseGuides/EC/2016_EC1...
# ...                                                        ...
# ST308        https://www.lse.ac.uk/courseGuides/ST/2016_ST3...
# ST327        https://www.lse.ac.uk/courseGuides/ST/2016_ST3...
# AC104        https://www.lse.ac.uk/courseGuides/AC/2016_AC1...
# GY240        https://www.lse.ac.uk/courseGuides/GY/2016_GY2...
# MG303        https://www.lse.ac.uk/courseGuides/MG/2016_MG3...
#
# [331 rows x 1 columns]
# Page not found: https://www.lse.ac.uk/courseGuides/AC/2016_AC100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN101.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN102.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC102.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EH/2016_EH101.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EH/2016_EH102.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV101.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY103.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY120.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY121.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY140.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY113.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY116.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY118.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL104.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL105.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL106.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL108.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL109.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN101.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN102.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN104.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN110.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN112.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN120.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN121.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN122.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN130.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN131.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN132.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN140.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN142.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN200.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN210.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN220.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN230.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN240.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN250.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN251.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN252.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN253.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN254.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN270.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN320.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LN/2016_LN330.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AC/2016_AC340.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA103.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA107.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA110.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG101.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG102.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG103.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH101.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH103.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH104.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PS/2016_PS102.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PS/2016_PS110.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA101.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA103.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA104.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA105.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO100.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO102.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO110.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST102.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST107.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST108.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AC/2016_AC211.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AC/2016_AC310.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AC/2016_AC330.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN200.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN205.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN216.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN221.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN223.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN226.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN237.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN238.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN240.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN243.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN244.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN247.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN250.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN251.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN252.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN256.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN269.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN274.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN275.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AN/2016_AN298.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC201.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC202.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC210.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC220.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC221.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC230.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC301.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC302.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC303.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC307.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC309.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC310.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC311.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC313.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC315.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC317.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC319.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC321.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC325.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EC/2016_EC333.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EH/2016_EH204.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EH/2016_EH207.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EH/2016_EH211.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EH/2016_EH225.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EH/2016_EH238.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EH/2016_EH240.htm
# Page not found: https://www.lse.ac.uk/courseGuides/EH/2016_EH307.htm
# Page not found: https://www.lse.ac.uk/courseGuides/FM/2016_FM212.htm
# Page not found: https://www.lse.ac.uk/courseGuides/FM/2016_FM300.htm
# Page not found: https://www.lse.ac.uk/courseGuides/FM/2016_FM320.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GI/2016_GI200.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV225.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV227.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV245.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV248.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV249.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV251.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV262.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV263.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV264.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV302.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV306.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV312.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV315.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV316.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV317.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV318.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV325.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GV/2016_GV335.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY200.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY201.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY202.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY205.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY220.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY222.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY244.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY300.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY301.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY302.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY303.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY305.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY306.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY324.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY325.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY200.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY203.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY206.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY221.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY226.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY232.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY233.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY235.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY238.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY239.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY240.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY241.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY242.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY243.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY311.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY315.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY319.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY320.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY321.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY322.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY323.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY324.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY325.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY326.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY327.htm
# Page not found: https://www.lse.ac.uk/courseGuides/HY/2016_HY328.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR200.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR202.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR203.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR204.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR305.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR312.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR315.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR317.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR318.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR318.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR322.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR347.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR354.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR355.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR367.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR368.htm
# Page not found: https://www.lse.ac.uk/courseGuides/IR/2016_IR369.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL201.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL202.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL203.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL204.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL205.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL207.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL209.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL210.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL212.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL221.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL232.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL233.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL241.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL242.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL250.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL251.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL257.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL259.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL272.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL275.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL278.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL284.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL293.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL295.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL300.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL301.htm
# Page not found: https://www.lse.ac.uk/courseGuides/LL/2016_LL305.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA203.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA207.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA208.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA209.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA210.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA211.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA212.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA300.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA301.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA303.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA305.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA310.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA313.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA314.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA315.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA316.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA317.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA318.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA319.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MA/2016_MA320.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG203.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG205.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG206.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG207.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG208.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG209.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG210.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG211.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG212.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG213.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG214.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG228.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG301.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG302.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG304.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG305.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG306.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG307.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG308.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG309.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG310.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG311.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG312.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG313.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG315.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH201.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH203.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH214.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH217.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH221.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH222.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH227.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH228.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH229.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH230.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH232.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH311.htm
# Page not found: https://www.lse.ac.uk/courseGuides/PH/2016_PH332.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA201.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA204.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA217.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA218.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA219.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA221.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA223.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA250.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA302.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA309.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SA/2016_SA320.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO201.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO203.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO208.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO210.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO211.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO221.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO224.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO230.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO231.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO308.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO309.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO310.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO311.htm
# Page not found: https://www.lse.ac.uk/courseGuides/SO/2016_SO312.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST201.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST202.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST205.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST226.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST227.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST300.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST302.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST304.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST306.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST307.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST308.htm
# Page not found: https://www.lse.ac.uk/courseGuides/ST/2016_ST327.htm
# Page not found: https://www.lse.ac.uk/courseGuides/AC/2016_AC104.htm
# Page not found: https://www.lse.ac.uk/courseGuides/GY/2016_GY240.htm
# Page not found: https://www.lse.ac.uk/courseGuides/MG/2016_MG303.htm
# Course Prerequisites DataFrame:
#              Prerequisites
# Course Code
# AC100                    0
# AN100                    0
# AN101                    0
# AN102                    0
# EC100                    0
# ...                    ...
# ST308                    0
# ST327                    0
# AC104                    0
# GY240                    0
# MG303                    0
#
# [331 rows x 1 columns]

# %%
# Function to extract prerequisites from a course page
def get_prerequisites(course_url):
    try:
        # Send a GET request to the course page
        page = requests.get(course_url)
        soup = BeautifulSoup(page.content, "lxml")

        # Look for a possible prerequisite heading (commonly 'Prerequisite')
        prereq_section = soup.find(string=lambda text: 'prerequisite' in text.lower())
        
        if prereq_section:
            # Find the parent tag of the prereq section and try to extract course codes
            prereqs = []
            for link in prereq_section.find_parent().find_all('a', href=True):
                course_code = link.get_text(strip=True)
                # Check if the text is a valid course code (starts with letters and followed by numbers)
                if len(course_code) >= 5 and course_code[:2].isalpha() and course_code[2:].isdigit():
                    prereqs.append(course_code)
            
            # Return prerequisites if found, otherwise return [0]
            return prereqs if prereqs else [0]
        return [0]  # No prerequisites found
        
    except Exception as e:
        # Handle errors gracefully and return 0 in case of failure
        print(f"Error fetching prerequisites for {course_url}: {e}")
        return [0]


# Now, let's extract the prerequisites for each course from the dataframe
course_data_with_prereqs = []

# Loop through each course in the DataFrame
for index, row in df_courses.iterrows():
    course_code = index
    course_url = row['URL']
    
    # Get prerequisites for the course
    prerequisites = get_prerequisites(course_url)
    
    # Append the course data with prerequisites to the list
    for prereq in prerequisites:
        course_data_with_prereqs.append({'Course Code': course_code, 'Prerequisites': prereq})

# Create a new DataFrame with the course codes and their prerequisites
df_prereqs = pd.DataFrame(course_data_with_prereqs)

# Set 'Course Code' as the index column
df_prereqs.set_index('Course Code', inplace=True)

# Display the DataFrame with prerequisites
print(df_prereqs)
# Out:
#              Prerequisites
# Course Code
# AC100                    0
# AN100                    0
# AN101                    0
# AN102                    0
# EC100                    0
# ...                    ...
# ST308                    0
# ST327                    0
# AC104                    0
# GY240                    0
# MG303                    0
#
# [331 rows x 1 columns]

# %%
import pandas as pd

# Replace 'your_file.xlsx' with the actual path to your Excel file
df = pd.read_excel("financem.xlsx")

print(df)
# Out:
#    Module  Year  Optional/Compulsory Prerequisites  Units
# 0   MA108     1                    0             0    0.5
# 1   FM100     1                    0             0    0.5
# 2   FM102     1                    0             0    0.5
# 3   EC1A3     1                    0             0    0.5
# 4   EC1B3     1                    0             0    0.5
# 5   ST102     1                    0             0    1.0
# 6   AC102     1                    1             0    0.5
# 7   ST101     1                    1             0    0.5
# 8   FM201     2                    0             0    0.5
# 9   FM200     2                    0             0    0.5
# 10  EC2C3     2                    0             0    0.5
# 11  EC2C4     2                    0             0    0.5
# 12  EC2A3     2                    0             0    0.5
# 13  FM215     2                    0             0    0.5
# 14  FM214     2                    0             0    0.5
# 15  ST115     2                    1             0    0.5
# 16  FM301     3                    0             0    0.5
# 17  FM302     3                    0             0    0.5
# 18  FM321     3                    0             0    0.5
# 19  FM322     3                    0             0    0.5
# 20  FM304     3                    0             0    0.5
# 21  FM305     3                    0             0    0.5
# 22  ST310     3                    1             0    0.5
# 23  ST311     3                    1             0    0.5
# 24  AC205     2                    1         AC102    0.5
# 25  AC206     2                    1         AC102    0.5

# %%
import pandas as pd
import itertools

# Define your data (corrected lengths)
data = {
    'Module': ['MA108', 'FM100', 'FM102', 'EC1A3', 'EC1B3', 'ST102', 'AC102', 'ST101',
               'FM201', 'FM200', 'EC2C3', 'EC2C4', 'EC2A3', 'FM215', 'FM214', 'ST115',
               'FM301', 'FM302', 'FM321', 'FM322', 'FM304', 'FM305', 'ST310', 'ST311',
               'AC205', 'AC206'],
    'Year': [1]*8 + [2]*8 + [3]*8 + [2, 2],
    'Optional/Compulsory': [0]*6 + [1, 1] + [0]*14 + [1, 1],
    'Prerequisites': [0]*22 + ['AC102', 'AC102'],
    'Units': [0.5]*26
}

df = pd.DataFrame(data)

# Separate compulsory and optional modules
compulsory = df[df['Optional/Compulsory'] == 0]
optional = df[df['Optional/Compulsory'] == 1]

# Get all compulsory modules
compulsory_modules = compulsory['Module'].tolist()
compulsory_units = compulsory['Units'].sum()

# Prerequisite map for optional modules
prereq_map = dict(zip(optional['Module'], optional['Prerequisites']))

# Store valid combinations
valid_combinations = []

# Generate all combinations of optional modules
for r in range(0, len(optional)+1):
    for combo in itertools.combinations(optional.itertuples(index=False), r):
        modules = [mod.Module for mod in combo]
        units = sum(mod.Units for mod in combo)

        # Check prerequisites
        valid = True
        for mod in combo:
            prereq = prereq_map[mod.Module]
            if prereq != 0 and prereq not in modules and prereq not in compulsory_modules:
                valid = False
                break

        if valid and compulsory_units + units == 12:
            full_combo = compulsory_modules + modules
            valid_combinations.append(full_combo)

# Convert to DataFrame
result_df = pd.DataFrame(valid_combinations)
print(result_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 16
#       4 # Define your data (corrected lengths)
#       5 data = {
#       6     'Module': ['MA108', 'FM100', 'FM102', 'EC1A3', 'EC1B3', 'ST102', 'AC102', 'ST101',
#       7                'FM201', 'FM200', 'EC2C3', 'EC2C4', 'EC2A3', 'FM215', 'FM214', 'ST115',
#    (...)
#      13     'Units': [0.5]*26
#      14 }
# ---> 16 df = pd.DataFrame(data)
#      18 # Separate compulsory and optional modules
#      19 compulsory = df[df['Optional/Compulsory'] == 0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length
